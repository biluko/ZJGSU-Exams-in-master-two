# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
from torch.utils.tensorboard import SummaryWriter
import numpy as np
import cv2
from PIL import Image

# %%
input_size = 28
num_classes = 10
num_epochs = 20
batch_size = 128

train_dataset = torchvision.datasets.MNIST(root='data',
                              train=True,
                              transform=torchvision.transforms.ToTensor())

test_dataset = torchvision.datasets.MNIST(root='data',
                             train=False,
                             transform=torchvision.transforms.ToTensor())

# %%
#构建 mini-batch
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=batch_size,
                                          shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=True)

# %%
#构建 网络结构
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Sequential(nn.Conv2d(in_channels=1,
                                             out_channels=8,
                                             kernel_size=5,
                                             stride=1,
                                             padding=2),
                                   nn.ReLU(),
                                   nn.MaxPool2d(kernel_size=2),)
        self.conv2 = nn.Sequential(nn.Conv2d(8, 16, 5, 1, 2),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2),)
        self.out = nn.Linear(16 * 7 * 7, 10)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)
        output = self.out(x)
        return output

# %%
#定义准确率作为评估标准
def accuracy(predictions, labels):
    pred = torch.max(predictions.data, 1)[1]            #torch.max()[0]返回最大值 torch.max()[1]返回最大值位置，既预测值
    rights = pred.eq(labels.data.view_as(pred)).sum()
    return rights, len(labels)                          #这里返回的是正确个数与总个数组成的元组

# %%
net = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.cuda()

for epoch in range(num_epochs):
    train_rights = []
    
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.cuda(), target.cuda()
        net.train()
        output = torch.softmax(net(data), dim=1)
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        right = accuracy(output, target)
        train_rights.append(right)
        
        if batch_idx % 100 == 0:
            net.eval()
            val_rights = []
            
            for (data, target) in test_loader:
                data, target = data.cuda(), target.cuda()#测试数据传入显存
                output = net(data)
                right = accuracy(output, target)
                val_rights.append(right)
            
            train_r = (sum([tup[0] for tup in train_rights]), sum([tup[1] for tup in train_rights]))
            val_r = (sum([tup[0] for tup in val_rights]), sum([tup[1] for tup in val_rights]))
            
            print(f'当前epoch：{epoch} [{batch_idx*batch_size}/{len(train_loader.dataset)}]   损失：{loss.data:.6f}  训练集准确率：{100*train_r[0]/train_r[1]:.2f}%   测试集准确率：{100*val_r[0]/val_r[1]:.2f}%')
# Out:
# 当前epoch：0 [0/60000]   损失：2.302480  训练集准确率：12.50%   测试集准确率：11.97%
# 当前epoch：0 [12800/60000]   损失：1.707443  训练集准确率：60.14%   测试集准确率：81.31%
# 当前epoch：0 [25600/60000]   损失：1.598603  训练集准确率：71.16%   测试集准确率：84.05%
# 当前epoch：0 [38400/60000]   损失：1.589960  训练集准确率：75.41%   测试集准确率：84.87%
# 当前epoch：0 [51200/60000]   损失：1.607264  训练集准确率：77.67%   测试集准确率：85.95%
# 当前epoch：1 [0/60000]   损失：1.620426  训练集准确率：84.38%   测试集准确率：86.64%
# 当前epoch：1 [12800/60000]   损失：1.600156  训练集准确率：85.94%   测试集准确率：87.01%
# 当前epoch：1 [25600/60000]   损失：1.605415  训练集准确率：86.43%   测试集准确率：87.22%
# 当前epoch：1 [38400/60000]   损失：1.529931  训练集准确率：86.94%   测试集准确率：95.37%
# 当前epoch：1 [51200/60000]   损失：1.510738  训练集准确率：88.97%   测试集准确率：95.78%
# 当前epoch：2 [0/60000]   损失：1.529776  训练集准确率：93.75%   测试集准确率：96.04%
# 当前epoch：2 [12800/60000]   损失：1.497789  训练集准确率：95.92%   测试集准确率：96.83%
# 当前epoch：2 [25600/60000]   损失：1.492424  训练集准确率：96.29%   测试集准确率：96.91%
# 当前epoch：2 [38400/60000]   损失：1.491920  训练集准确率：96.31%   测试集准确率：97.06%
# 当前epoch：2 [51200/60000]   损失：1.491367  训练集准确率：96.46%   测试集准确率：97.29%
# 当前epoch：3 [0/60000]   损失：1.513703  训练集准确率：94.53%   测试集准确率：97.07%
# 当前epoch：3 [12800/60000]   损失：1.491493  训练集准确率：97.24%   测试集准确率：96.34%
# 当前epoch：3 [25600/60000]   损失：1.481342  训练集准确率：97.19%   测试集准确率：97.20%
# 当前epoch：3 [38400/60000]   损失：1.503595  训练集准确率：97.24%   测试集准确率：97.78%
# 当前epoch：3 [51200/60000]   损失：1.485214  训练集准确率：97.26%   测试集准确率：97.40%
# 当前epoch：4 [0/60000]   损失：1.492891  训练集准确率：96.88%   测试集准确率：97.47%
# 当前epoch：4 [12800/60000]   损失：1.500337  训练集准确率：97.41%   测试集准确率：97.88%
# 当前epoch：4 [25600/60000]   损失：1.489242  训练集准确率：97.50%   测试集准确率：97.86%
# 当前epoch：4 [38400/60000]   损失：1.486120  训练集准确率：97.60%   测试集准确率：97.92%
# 当前epoch：4 [51200/60000]   损失：1.478941  训练集准确率：97.59%   测试集准确率：97.97%
# 当前epoch：5 [0/60000]   损失：1.478984  训练集准确率：98.44%   测试集准确率：97.96%
# 当前epoch：5 [12800/60000]   损失：1.477791  训练集准确率：98.17%   测试集准确率：98.14%
# 当前epoch：5 [25600/60000]   损失：1.486027  训练集准确率：98.01%   测试集准确率：97.93%
# 当前epoch：5 [38400/60000]   损失：1.504088  训练集准确率：97.97%   测试集准确率：97.95%
# 当前epoch：5 [51200/60000]   损失：1.487582  训练集准确率：98.00%   测试集准确率：97.96%
# 当前epoch：6 [0/60000]   损失：1.484601  训练集准确率：97.66%   测试集准确率：97.54%
# 当前epoch：6 [12800/60000]   损失：1.485792  训练集准确率：97.97%   测试集准确率：97.98%
# 当前epoch：6 [25600/60000]   损失：1.477216  训练集准确率：98.02%   测试集准确率：98.06%
# 当前epoch：6 [38400/60000]   损失：1.488337  训练集准确率：98.05%   测试集准确率：98.24%
# 当前epoch：6 [51200/60000]   损失：1.469546  训练集准确率：98.13%   测试集准确率：98.05%
# 当前epoch：7 [0/60000]   损失：1.487230  训练集准确率：97.66%   测试集准确率：98.30%
# 当前epoch：7 [12800/60000]   损失：1.463305  训练集准确率：98.35%   测试集准确率：98.25%
# 当前epoch：7 [25600/60000]   损失：1.471605  训练集准确率：98.25%   测试集准确率：97.83%
# 当前epoch：7 [38400/60000]   损失：1.478093  训练集准确率：98.23%   测试集准确率：98.06%
# 当前epoch：7 [51200/60000]   损失：1.495240  训练集准确率：98.25%   测试集准确率：97.95%
# 当前epoch：8 [0/60000]   损失：1.472828  训练集准确率：98.44%   测试集准确率：98.24%
# 当前epoch：8 [12800/60000]   损失：1.479645  训练集准确率：98.55%   测试集准确率：98.39%
# 当前epoch：8 [25600/60000]   损失：1.483615  训练集准确率：98.50%   测试集准确率：98.61%
# 当前epoch：8 [38400/60000]   损失：1.482804  训练集准确率：98.47%   测试集准确率：98.27%
# 当前epoch：8 [51200/60000]   损失：1.476876  训练集准确率：98.47%   测试集准确率：98.32%
# 当前epoch：9 [0/60000]   损失：1.462301  训练集准确率：100.00%   测试集准确率：98.57%
# 当前epoch：9 [12800/60000]   损失：1.485504  训练集准确率：98.52%   测试集准确率：98.42%
# 当前epoch：9 [25600/60000]   损失：1.473274  训练集准确率：98.54%   测试集准确率：98.48%
# 当前epoch：9 [38400/60000]   损失：1.479799  训练集准确率：98.56%   测试集准确率：98.48%
# 当前epoch：9 [51200/60000]   损失：1.476045  训练集准确率：98.60%   测试集准确率：98.26%
# 当前epoch：10 [0/60000]   损失：1.473860  训练集准确率：99.22%   测试集准确率：98.39%
# 当前epoch：10 [12800/60000]   损失：1.468199  训练集准确率：98.58%   测试集准确率：98.54%
# 当前epoch：10 [25600/60000]   损失：1.483874  训练集准确率：98.62%   测试集准确率：98.38%
# 当前epoch：10 [38400/60000]   损失：1.472938  训练集准确率：98.66%   测试集准确率：98.61%
# 当前epoch：10 [51200/60000]   损失：1.466449  训练集准确率：98.66%   测试集准确率：98.55%
# 当前epoch：11 [0/60000]   损失：1.469843  训练集准确率：99.22%   测试集准确率：98.39%
# 当前epoch：11 [12800/60000]   损失：1.475754  训练集准确率：98.69%   测试集准确率：98.58%
# 当前epoch：11 [25600/60000]   损失：1.466287  训练集准确率：98.71%   测试集准确率：98.68%
# 当前epoch：11 [38400/60000]   损失：1.474181  训练集准确率：98.76%   测试集准确率：98.38%
# 当前epoch：11 [51200/60000]   损失：1.462048  训练集准确率：98.75%   测试集准确率：98.64%
# 当前epoch：12 [0/60000]   损失：1.476925  训练集准确率：98.44%   测试集准确率：98.60%
# 当前epoch：12 [12800/60000]   损失：1.476905  训练集准确率：98.79%   测试集准确率：98.67%
# 当前epoch：12 [25600/60000]   损失：1.470966  训练集准确率：98.80%   测试集准确率：98.64%
# 当前epoch：12 [38400/60000]   损失：1.467653  训练集准确率：98.82%   测试集准确率：98.47%
# 当前epoch：12 [51200/60000]   损失：1.478690  训练集准确率：98.79%   测试集准确率：98.50%
# 当前epoch：13 [0/60000]   损失：1.495574  训练集准确率：96.88%   测试集准确率：98.68%
# 当前epoch：13 [12800/60000]   损失：1.468993  训练集准确率：98.87%   测试集准确率：98.65%
# 当前epoch：13 [25600/60000]   损失：1.461713  训练集准确率：98.88%   测试集准确率：98.67%
# 当前epoch：13 [38400/60000]   损失：1.481260  训练集准确率：98.89%   测试集准确率：98.77%
# 当前epoch：13 [51200/60000]   损失：1.485260  训练集准确率：98.86%   测试集准确率：98.70%
# 当前epoch：14 [0/60000]   损失：1.469631  训练集准确率：99.22%   测试集准确率：98.58%
# 当前epoch：14 [12800/60000]   损失：1.465393  训练集准确率：98.95%   测试集准确率：98.70%
# 当前epoch：14 [25600/60000]   损失：1.496279  训练集准确率：98.90%   测试集准确率：98.45%
# 当前epoch：14 [38400/60000]   损失：1.464009  训练集准确率：98.89%   测试集准确率：98.65%
# 当前epoch：14 [51200/60000]   损失：1.474166  训练集准确率：98.88%   测试集准确率：98.35%
# 当前epoch：15 [0/60000]   损失：1.461833  训练集准确率：100.00%   测试集准确率：98.91%
# 当前epoch：15 [12800/60000]   损失：1.467093  训练集准确率：99.03%   测试集准确率：98.67%
# 当前epoch：15 [25600/60000]   损失：1.468967  训练集准确率：99.08%   测试集准确率：98.74%
# 当前epoch：15 [38400/60000]   损失：1.469782  训练集准确率：99.03%   测试集准确率：98.72%
# 当前epoch：15 [51200/60000]   损失：1.474556  训练集准确率：99.00%   测试集准确率：98.66%
# 当前epoch：16 [0/60000]   损失：1.476555  训练集准确率：98.44%   测试集准确率：98.53%
# 当前epoch：16 [12800/60000]   损失：1.461714  训练集准确率：98.96%   测试集准确率：98.86%
# 当前epoch：16 [25600/60000]   损失：1.476779  训练集准确率：98.95%   测试集准确率：98.60%
# 当前epoch：16 [38400/60000]   损失：1.475333  训练集准确率：99.01%   测试集准确率：98.55%
# 当前epoch：16 [51200/60000]   损失：1.475766  训练集准确率：98.99%   测试集准确率：98.69%
# 当前epoch：17 [0/60000]   损失：1.461252  训练集准确率：100.00%   测试集准确率：98.67%
# 当前epoch：17 [12800/60000]   损失：1.461874  训练集准确率：99.13%   测试集准确率：98.89%
# 当前epoch：17 [25600/60000]   损失：1.470100  训练集准确率：99.04%   测试集准确率：98.76%
# 当前epoch：17 [38400/60000]   损失：1.461566  训练集准确率：99.01%   测试集准确率：98.73%
# 当前epoch：17 [51200/60000]   损失：1.486558  训练集准确率：98.98%   测试集准确率：98.73%
# 当前epoch：18 [0/60000]   损失：1.462950  训练集准确率：100.00%   测试集准确率：98.83%
# 当前epoch：18 [12800/60000]   损失：1.477037  训练集准确率：99.14%   测试集准确率：98.61%
# 当前epoch：18 [25600/60000]   损失：1.473549  训练集准确率：99.00%   测试集准确率：98.68%
# 当前epoch：18 [38400/60000]   损失：1.471747  训练集准确率：99.06%   测试集准确率：98.75%
# 当前epoch：18 [51200/60000]   损失：1.468914  训练集准确率：99.06%   测试集准确率：98.76%
# 当前epoch：19 [0/60000]   损失：1.469646  训练集准确率：99.22%   测试集准确率：98.83%
# 当前epoch：19 [12800/60000]   损失：1.469166  训练集准确率：99.20%   测试集准确率：98.86%
# 当前epoch：19 [25600/60000]   损失：1.461990  训练集准确率：99.18%   测试集准确率：98.76%
# 当前epoch：19 [38400/60000]   损失：1.462651  训练集准确率：99.16%   测试集准确率：98.86%
# 当前epoch：19 [51200/60000]   损失：1.469140  训练集准确率：99.14%   测试集准确率：98.76%

# %%
def plot_conv(writer, model):
    for name,param in model.named_parameters():
        if 'conv' in name and 'weight' in name:
            in_channels = param.size()[1]	# 输入通道
            out_channels = param.size()[0]   # 输出通道
            k_w, k_h = param.size()[3], param.size()[2]   # 卷积核的尺寸
            kernel_all = param.view(-1, 1, k_w, k_h)  # 每个通道的卷积核
            kernel_grid = torchvision.utils.make_grid(kernel_all, normalize=True, scale_each=True, nrow=in_channels)
            writer.add_image(f'{name}_all', kernel_grid, global_step=0)

# %%
writer = SummaryWriter("logs")
plot_conv(writer, net)
