# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import numpy as np
import pandas as pd
import cv2
from PIL import Image

# %%
input_size = 28
num_classes = 10
num_epochs = 20
batch_size = 500

data_transforms = {
        'train': torchvision.transforms.Compose([
            torchvision.transforms.ToTensor()
            , torchvision.transforms.RandomCrop(32, padding=4)  # 先四周填充0，在吧图像随机裁剪成32*32
            , torchvision.transforms.RandomHorizontalFlip(p=0.5)  # 随机水平翻转 选择一个概率概率
            , torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # 均值，标准差
        ]),
        'valid': torchvision.transforms.Compose([
            torchvision.transforms.ToTensor()
            , torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
    }

train_dataset = torchvision.datasets.CIFAR10(root='data',
                              train=True,
                              transform=data_transforms['train'])

test_dataset = torchvision.datasets.CIFAR10(root='data',
                             train=False,
                             transform=data_transforms['valid'])

# %%
#构建 mini-batch
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                          batch_size=batch_size,
                                          shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=True)

# %%
#定义准确率作为评估标准
def accuracy(predictions, labels):
    pred = torch.max(predictions.data, 1)[1]            #torch.max()[0]返回最大值 torch.max()[1]返回最大值位置，既预测值
    rights = pred.eq(labels.data.view_as(pred)).sum()
    return rights, len(labels)                          #这里返回的是正确个数与总个数组成的元组

# %%
class ResidualBlock(nn.Module):
    def __init__(self, inchannel, outchannel, stride=1):
        super(ResidualBlock, self).__init__()
        self.left = nn.Sequential(
            nn.Conv2d(inchannel, outchannel, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(outchannel),
            nn.ReLU(inplace=True),
            nn.Conv2d(outchannel, outchannel, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(outchannel)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or inchannel != outchannel:
            self.shortcut = nn.Sequential(
                nn.Conv2d(inchannel, outchannel, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(outchannel)
            )

    def forward(self, x):
        out = self.left(x)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, ResidualBlock, num_classes=10):
        super(ResNet, self).__init__()
        self.inchannel = 64
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        )
        self.layer1 = self.make_layer(ResidualBlock, 64,  2, stride=1)
        self.layer2 = self.make_layer(ResidualBlock, 128, 2, stride=2)
        self.layer3 = self.make_layer(ResidualBlock, 256, 2, stride=2)
        self.layer4 = self.make_layer(ResidualBlock, 512, 2, stride=2)
        self.fc = nn.Linear(512, num_classes)

    def make_layer(self, block, channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)   #strides=[1,1]
        layers = []
        for stride in strides:
            layers.append(block(self.inchannel, channels, stride))
            self.inchannel = channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

def ResNet18():

    return ResNet(ResidualBlock)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class ResidualBlock(nn.Module):
#       2     def __init__(self, inchannel, outchannel, stride=1):
#       3         super(ResidualBlock, self).__init__()
#
# NameError: name 'nn' is not defined

# %%
net = ResNet18()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.cuda()
test_right = []
train_loss = []

for epoch in range(num_epochs):
    train_rights = []
    
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.cuda(), target.cuda()
        net.train()
        output = net(data)
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        right = accuracy(output, target)
        train_rights.append(right)
        
        if batch_idx % 50 == 0:
            net.eval()
            val_rights = []
            
            for (data, target) in test_loader:
                data, target = data.cuda(), target.cuda()
                output = net(data)
                right = accuracy(output, target)
                val_rights.append(right)
            
            train_r = (sum([tup[0] for tup in train_rights]), sum([tup[1] for tup in train_rights]))
            val_r = (sum([tup[0] for tup in val_rights]), sum([tup[1] for tup in val_rights]))
            test_right.append((100*val_r[0]/val_r[1]).cpu().numpy())
            train_loss.append(loss.data.cpu().numpy())

            print(f'当前epoch：{epoch} [{batch_idx*batch_size}/{len(train_loader.dataset)}]   损失：{loss.data:.6f}  训练集准确率：{100*train_r[0]/train_r[1]:.2f}%   测试集准确率：{100*val_r[0]/val_r[1]:.2f}%')
# Out:
# 当前epoch：0 [0/50000]   损失：2.394521  训练集准确率：13.50%   测试集准确率：11.41%
# 当前epoch：0 [20000/50000]   损失：1.473894  训练集准确率：35.65%   测试集准确率：39.02%
# 当前epoch：0 [40000/50000]   损失：1.275994  训练集准确率：42.58%   测试集准确率：50.19%
# 当前epoch：1 [0/50000]   损失：1.172294  训练集准确率：56.50%   测试集准确率：50.43%
# 当前epoch：1 [20000/50000]   损失：0.999227  训练集准确率：61.82%   测试集准确率：59.23%
# 当前epoch：1 [40000/50000]   损失：0.914390  训练集准确率：63.68%   测试集准确率：63.22%
# 当前epoch：2 [0/50000]   损失：0.783401  训练集准确率：72.50%   测试集准确率：49.70%
# 当前epoch：2 [20000/50000]   损失：0.680087  训练集准确率：73.34%   测试集准确率：64.01%
# 当前epoch：2 [40000/50000]   损失：0.816586  训练集准确率：73.98%   测试集准确率：66.11%
# 当前epoch：3 [0/50000]   损失：0.547403  训练集准确率：81.00%   测试集准确率：71.57%
# 当前epoch：3 [20000/50000]   损失：0.492232  训练集准确率：80.33%   测试集准确率：73.34%
# 当前epoch：3 [40000/50000]   损失：0.488866  训练集准确率：80.28%   测试集准确率：76.01%
# 当前epoch：4 [0/50000]   损失：0.431932  训练集准确率：84.50%   测试集准确率：76.70%
# 当前epoch：4 [20000/50000]   损失：0.439816  训练集准确率：84.58%   测试集准确率：74.67%
# 当前epoch：4 [40000/50000]   损失：0.479009  训练集准确率：84.56%   测试集准确率：74.92%
# 当前epoch：5 [0/50000]   损失：0.298967  训练集准确率：90.50%   测试集准确率：77.86%
# 当前epoch：5 [20000/50000]   损失：0.318000  训练集准确率：88.85%   测试集准确率：77.91%
# 当前epoch：5 [40000/50000]   损失：0.333850  训练集准确率：88.52%   测试集准确率：76.77%
# 当前epoch：6 [0/50000]   损失：0.208795  训练集准确率：93.25%   测试集准确率：76.59%
# 当前epoch：6 [20000/50000]   损失：0.301899  训练集准确率：91.71%   测试集准确率：80.45%
# 当前epoch：6 [40000/50000]   损失：0.292478  训练集准确率：91.16%   测试集准确率：80.16%
# 当前epoch：7 [0/50000]   损失：0.170781  训练集准确率：93.25%   测试集准确率：78.40%
# 当前epoch：7 [20000/50000]   损失：0.164995  训练集准确率：94.41%   测试集准确率：77.87%
# 当前epoch：7 [40000/50000]   损失：0.222190  训练集准确率：93.97%   测试集准确率：77.52%
# 当前epoch：8 [0/50000]   损失：0.117091  训练集准确率：95.75%   测试集准确率：79.43%
# 当前epoch：8 [20000/50000]   损失：0.127393  训练集准确率：95.82%   测试集准确率：79.03%
# 当前epoch：8 [40000/50000]   损失：0.151288  训练集准确率：95.37%   测试集准确率：75.67%
# 当前epoch：9 [0/50000]   损失：0.084293  训练集准确率：97.50%   测试集准确率：79.96%
# 当前epoch：9 [20000/50000]   损失：0.087831  训练集准确率：96.93%   测试集准确率：80.87%
# 当前epoch：9 [40000/50000]   损失：0.126167  训练集准确率：96.81%   测试集准确率：79.16%
# 当前epoch：10 [0/50000]   损失：0.069935  训练集准确率：98.00%   测试集准确率：77.52%
# 当前epoch：10 [20000/50000]   损失：0.094500  训练集准确率：97.32%   测试集准确率：81.67%
# 当前epoch：10 [40000/50000]   损失：0.091533  训练集准确率：97.19%   测试集准确率：78.95%
# 当前epoch：11 [0/50000]   损失：0.041559  训练集准确率：98.50%   测试集准确率：76.50%
# 当前epoch：11 [20000/50000]   损失：0.041366  训练集准确率：98.43%   测试集准确率：81.45%
# 当前epoch：11 [40000/50000]   损失：0.047861  训练集准确率：98.42%   测试集准确率：80.65%
# 当前epoch：12 [0/50000]   损失：0.038107  训练集准确率：98.75%   测试集准确率：79.07%
# 当前epoch：12 [20000/50000]   损失：0.068400  训练集准确率：98.44%   测试集准确率：82.17%
# 当前epoch：12 [40000/50000]   损失：0.027007  训练集准确率：98.50%   测试集准确率：82.11%
# 当前epoch：13 [0/50000]   损失：0.028313  训练集准确率：99.50%   测试集准确率：80.91%
# 当前epoch：13 [20000/50000]   损失：0.043599  训练集准确率：98.64%   测试集准确率：81.63%
# 当前epoch：13 [40000/50000]   损失：0.052110  训练集准确率：98.44%   测试集准确率：81.29%
# 当前epoch：14 [0/50000]   损失：0.028675  训练集准确率：99.25%   测试集准确率：75.58%
# 当前epoch：14 [20000/50000]   损失：0.075834  训练集准确率：98.29%   测试集准确率：80.02%
# 当前epoch：14 [40000/50000]   损失：0.033022  训练集准确率：98.46%   测试集准确率：80.66%
# 当前epoch：15 [0/50000]   损失：0.050042  训练集准确率：97.50%   测试集准确率：79.05%
# 当前epoch：15 [20000/50000]   损失：0.032737  训练集准确率：98.88%   测试集准确率：82.68%
# 当前epoch：15 [40000/50000]   损失：0.030907  训练集准确率：98.82%   测试集准确率：81.60%
# 当前epoch：16 [0/50000]   损失：0.024758  训练集准确率：99.25%   测试集准确率：78.78%
# 当前epoch：16 [20000/50000]   损失：0.021250  训练集准确率：99.03%   测试集准确率：82.99%
# 当前epoch：16 [40000/50000]   损失：0.025064  训练集准确率：99.00%   测试集准确率：81.58%
# 当前epoch：17 [0/50000]   损失：0.039389  训练集准确率：98.75%   测试集准确率：79.69%
# 当前epoch：17 [20000/50000]   损失：0.030165  训练集准确率：98.89%   测试集准确率：81.26%
# 当前epoch：17 [40000/50000]   损失：0.039615  训练集准确率：98.82%   测试集准确率：76.94%
# 当前epoch：18 [0/50000]   损失：0.016432  训练集准确率：99.50%   测试集准确率：80.43%
# 当前epoch：18 [20000/50000]   损失：0.033926  训练集准确率：98.91%   测试集准确率：81.51%
# 当前epoch：18 [40000/50000]   损失：0.019508  训练集准确率：98.92%   测试集准确率：82.52%
# 当前epoch：19 [0/50000]   损失：0.030177  训练集准确率：99.25%   测试集准确率：79.15%
# 当前epoch：19 [20000/50000]   损失：0.037569  训练集准确率：98.95%   测试集准确率：81.21%
# 当前epoch：19 [40000/50000]   损失：0.015240  训练集准确率：99.02%   测试集准确率：81.44%

# %%
#构建cnn
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Sequential(nn.Conv2d(in_channels=3,
                                             out_channels=32,
                                             kernel_size=5,
                                             stride=1,
                                             padding=2),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2),)
        self.conv2 = nn.Sequential(nn.Conv2d(32, 64, 5, 1, 2),
                                   nn.ReLU(),
                                   nn.MaxPool2d(2),)
        self.out = nn.Sequential(nn.Flatten(),
                                 nn.Linear(64 * 8 * 8, 256),
                                 nn.ReLU(),
                                 nn.Linear(256, 10),)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        output = self.out(x)
        return output

# %%
net = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)
net.cuda()
test_right = []
train_loss = []

for epoch in range(num_epochs):
    train_rights = []
    
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.cuda(), target.cuda()
        net.train()
        output = net(data)
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        right = accuracy(output, target)
        train_rights.append(right)
        
        if batch_idx % 50 == 0:
            net.eval()
            val_rights = []
            
            for (data, target) in test_loader:
                data, target = data.cuda(), target.cuda()
                output = net(data)
                right = accuracy(output, target)
                val_rights.append(right)
            
            train_r = (sum([tup[0] for tup in train_rights]), sum([tup[1] for tup in train_rights]))
            val_r = (sum([tup[0] for tup in val_rights]), sum([tup[1] for tup in val_rights]))
            test_right.append((100*val_r[0]/val_r[1]).cpu().numpy())
            train_loss.append(loss.data.cpu().numpy())

            print(f'当前epoch：{epoch} [{batch_idx*batch_size}/{len(train_loader.dataset)}]   损失：{loss.data:.6f}  训练集准确率：{100*train_r[0]/train_r[1]:.2f}%   测试集准确率：{100*val_r[0]/val_r[1]:.2f}%')
# Out:
# 当前epoch：0 [0/50000]   损失：2.300746  训练集准确率：10.20%   测试集准确率：19.05%
# 当前epoch：0 [25000/50000]   损失：1.566785  训练集准确率：33.63%   测试集准确率：45.66%
# 当前epoch：1 [0/50000]   损失：1.412195  训练集准确率：47.60%   测试集准确率：50.58%
# 当前epoch：1 [25000/50000]   损失：1.294514  训练集准确率：50.05%   测试集准确率：55.64%
# 当前epoch：2 [0/50000]   损失：1.304163  训练集准确率：53.60%   测试集准确率：58.87%
# 当前epoch：2 [25000/50000]   损失：1.230042  训练集准确率：56.93%   测试集准确率：60.32%
# 当前epoch：3 [0/50000]   损失：1.069164  训练集准确率：60.80%   测试集准确率：62.66%
# 当前epoch：3 [25000/50000]   损失：1.076782  训练集准确率：61.24%   测试集准确率：65.43%
# 当前epoch：4 [0/50000]   损失：1.043490  训练集准确率：63.80%   测试集准确率：66.14%
# 当前epoch：4 [25000/50000]   损失：1.006514  训练集准确率：64.18%   测试集准确率：65.96%
# 当前epoch：5 [0/50000]   损失：0.933830  训练集准确率：69.20%   测试集准确率：67.88%
# 当前epoch：5 [25000/50000]   损失：0.998918  训练集准确率：65.71%   测试集准确率：69.45%
# 当前epoch：6 [0/50000]   损失：0.980122  训练集准确率：65.00%   测试集准确率：70.26%
# 当前epoch：6 [25000/50000]   损失：0.881896  训练集准确率：68.00%   测试集准确率：69.67%
# 当前epoch：7 [0/50000]   损失：0.783719  训练集准确率：73.40%   测试集准确率：69.66%
# 当前epoch：7 [25000/50000]   损失：0.937106  训练集准确率：69.50%   测试集准确率：71.37%
# 当前epoch：8 [0/50000]   损失：0.831098  训练集准确率：73.00%   测试集准确率：71.23%
# 当前epoch：8 [25000/50000]   损失：0.873410  训练集准确率：69.99%   测试集准确率：71.96%
# 当前epoch：9 [0/50000]   损失：0.900720  训练集准确率：72.80%   测试集准确率：73.34%
# 当前epoch：9 [25000/50000]   损失：0.852231  训练集准确率：71.60%   测试集准确率：72.78%
# 当前epoch：10 [0/50000]   损失：0.804558  训练集准确率：70.20%   测试集准确率：73.43%
# 当前epoch：10 [25000/50000]   损失：0.764106  训练集准确率：72.16%   测试集准确率：73.35%
# 当前epoch：11 [0/50000]   损失：0.763482  训练集准确率：73.60%   测试集准确率：74.82%
# 当前epoch：11 [25000/50000]   损失：0.770828  训练集准确率：73.68%   测试集准确率：74.48%
# 当前epoch：12 [0/50000]   损失：0.739375  训练集准确率：73.80%   测试集准确率：73.80%
# 当前epoch：12 [25000/50000]   损失：0.844651  训练集准确率：74.08%   测试集准确率：74.25%
# 当前epoch：13 [0/50000]   损失：0.769377  训练集准确率：74.40%   测试集准确率：74.72%
# 当前epoch：13 [25000/50000]   损失：0.678416  训练集准确率：74.82%   测试集准确率：75.52%
# 当前epoch：14 [0/50000]   损失：0.733181  训练集准确率：74.40%   测试集准确率：75.78%
# 当前epoch：14 [25000/50000]   损失：0.652941  训练集准确率：76.06%   测试集准确率：76.07%
# 当前epoch：15 [0/50000]   损失：0.643979  训练集准确率：77.40%   测试集准确率：76.23%
# 当前epoch：15 [25000/50000]   损失：0.616403  训练集准确率：76.53%   测试集准确率：76.54%
# 当前epoch：16 [0/50000]   损失：0.612234  训练集准确率：80.00%   测试集准确率：77.07%
# 当前epoch：16 [25000/50000]   损失：0.760204  训练集准确率：76.85%   测试集准确率：76.71%
# 当前epoch：17 [0/50000]   损失：0.628783  训练集准确率：78.80%   测试集准确率：76.30%
# 当前epoch：17 [25000/50000]   损失：0.715514  训练集准确率：76.97%   测试集准确率：77.02%
# 当前epoch：18 [0/50000]   损失：0.622524  训练集准确率：79.20%   测试集准确率：76.63%
# 当前epoch：18 [25000/50000]   损失：0.687456  训练集准确率：77.66%   测试集准确率：77.16%
# 当前epoch：19 [0/50000]   损失：0.601553  训练集准确率：80.20%   测试集准确率：76.80%
# 当前epoch：19 [25000/50000]   损失：0.601776  训练集准确率：77.78%   测试集准确率：77.98%
